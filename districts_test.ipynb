# %%
import pandas as pd
import streamlit as st
import folium
from streamlit_folium import folium_static
import gpxpy
import requests
import json
import pymongo
import geopandas as gpd
from shapely.geometry import Point, shape
import dns
import numpy as np

# %%
#initialize mongo client and database
client = pymongo.MongoClient('mongodb+srv://doadmin:A79tz5F16P3Z84kW@berlin-map-db-d1b8496c.mongo.ondigitalocean.com/berlin-map?authSource=admin&replicaSet=berlin-map-db&tls=true&tlsCAFile=ca-certificate.crt')
db = client['berlin-map']

# %%
districts=list(db.districtcoordinates.find())
district_details=list(db.districtdetails.find())

# %%
cb_dist=[True, True, True, False, False, False, False, False, False, False, False, False]

coords_filtered=[x[1] for x in zip(cb_dist,coords) if x[0]==True]
district_details_filtered=[x[1] for x in zip(cb_dist,district_details) if x[0]==True]

# %%
m = folium.Map(location = [52.520008, 13.404954], tiles = "cartodbpositron", zoom_start=10)

for coords in coords_filtered:
    geo_j = folium.GeoJson(data=coords['geometry'],
                           style_function=lambda x: {'fillColor': 'orange'})
    folium.Popup(coords['properties']['Gemeinde_name']).add_to(geo_j)
    geo_j.add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
gpd.GeoSeries(coords[0]['geometry']['coordinates'])
# Out:
# <ipython-input-35-238a92d005e2>:1: FutureWarning:     You are passing non-geometry data to the GeoSeries constructor. Currently,
#     it falls back to returning a pandas Series. But in the future, we will start
#     to raise a TypeError instead.
#   gpd.GeoSeries(coords[0]['geometry']['coordinates'])
# 0    [[[13.320744327762688, 52.6265990635977], [13....
# dtype: object

# %%
sim_geo = gpd.GeoSeries(np.array(coords[0]))
geo_j = sim_geo.to_json()
# Out:
# <ipython-input-31-8a2c83273760>:1: FutureWarning:     You are passing non-geometry data to the GeoSeries constructor. Currently,
#     it falls back to returning a pandas Series. But in the future, we will start
#     to raise a TypeError instead.
#   sim_geo = gpd.GeoSeries(np.array(coords[0]))
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-8a2c83273760> in <module>
#       1 sim_geo = gpd.GeoSeries(np.array(coords[0]))
# ----> 2 geo_j = sim_geo.to_json()
#
# ~\anaconda3\envs\geo_env\lib\site-packages\pandas\core\generic.py in to_json(self, path_or_buf, orient, date_format, double_precision, force_ascii, date_unit, default_handler, lines, compression, index, indent, storage_options)
#    2464         indent = indent or 0
#    2465
# -> 2466         return json.to_json(
#    2467             path_or_buf=path_or_buf,
#    2468             obj=self,
#
# ...

# %%
coords[0].keys()
# Out:
# dict_keys(['_id', 'type', 'properties', 'geometry'])

# %%
db.districtdetails.remove()
# Out:
# <ipython-input-44-72c907f3cdd0>:1: DeprecationWarning: remove is deprecated. Use delete_one or delete_many instead.
#   db.districtdetails.remove()
# {'n': 12,
#  'opTime': {'ts': Timestamp(1625355333, 13), 't': 1},
#  'electionId': ObjectId('7fffffff0000000000000001'),
#  'ok': 1.0,
#  '$clusterTime': {'clusterTime': Timestamp(1625355333, 13),
#   'signature': {'hash': b'\xd7\x7fW\x8eF\xb2\xfd\x07\x0e\xac\x91\xcb\x87^Q\xe4"q\x98\xfb',
#    'keyId': 6980787307431329794}},
#  'operationTime': Timestamp(1625355333, 13)}
